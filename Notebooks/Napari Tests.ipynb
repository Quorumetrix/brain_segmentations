# %% [markdown]
# Note: Use with napari-env environment

# %%
from skimage import data
import napari

# %%
viewer = napari.view_image(data.astronaut(), rgb=True)
# Out:
# 2023-05-04 12:44:34 PM INFO     2023-05-04 12:44:34 PM - INFO - fancylog.py:321
#                                 MainProcess fancylog.py:321 -
#                                 Starting logging
#                        INFO     2023-05-04 12:44:34 PM - INFO - fancylog.py:322
#                                 MainProcess fancylog.py:322 -
#                                 Not logging multiple processes
# 2023-05-04 12:44:36 PM INFO     2023-05-04 12:44:36 PM - INFO -      util.py:34
#                                 MainProcess util.py:34 - Loading raw
#                                 image data
#                        INFO     2023-05-04 12:44:36 PM - INFO - register.py:428
#                                 MainProcess register.py:428 -
#                                 Registering
#                                 341880_413020_002040
# 2023-05-04 12:44:49 PM INFO     2023-05-04 12:44:49 PM - INFO - fancylog.py:321
#                                 MainProcess fancylog.py:321 -
# ...

# %%
brainreg brainglobe list
# Out:
#   Cell In[3], line 1
#     brainglobe list
#                ^
# SyntaxError: invalid syntax

# %%
viewer = napari.view_image()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 viewer = napari.view_image()
#
# File c:\Users\tyler\Anaconda3\envs\napari-env\lib\site-packages\napari\view_layers.py:179, in view_image(*args, **kwargs)
#     177 @_merge_layer_viewer_sigs_docs
#     178 def view_image(*args, **kwargs):
# --> 179     return _make_viewer_then('add_image', args, kwargs)[0]
#
# File c:\Users\tyler\Anaconda3\envs\napari-env\lib\site-packages\napari\view_layers.py:160, in _make_viewer_then(add_method, args, kwargs)
#     158 kwargs.update(kwargs.pop("kwargs", {}))
#     159 method = getattr(viewer, add_method)
# --> 160 added = method(*args, **kwargs)
#     161 if isinstance(added, list):
#     162     added = tuple(added)
#
# ...

# %%
'''brainreg /path/to/raw/data /path/to/output/directory -v 5 2 2 --orientation psl
If your plane spacing (i.e. the z-depth is 5 microns), and your in-plane resolution is 2x2 microns, then you would use:

-v 5 2 2

#The voxel sizes is x: 1.8 y: 1.8 and z: 4um. 
-v 4 1.8 1.8

# For the 5x downsampled:
-v 20 9 9

--atlas whs_sd_rat_39um'''
